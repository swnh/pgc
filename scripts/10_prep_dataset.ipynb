# %%
from nuscenes.nuscenes import NuScenes  
import numpy as np
import os
import sys

# %%
# NuScenes 데이터셋 경로 설정
nusc_path = "/home/swnh/pgc/datasets/nuscenes/v1.0-mini"

# NuScenes 인스턴스 생성
nusc = NuScenes(version='v1.0-mini', dataroot=nusc_path, verbose=True)

# NuScenes scenes 목록 출력
nusc.list_scenes()
# Out:
# ======
# Loading NuScenes tables for version v1.0-mini...
# Loading nuScenes-lidarseg...
# 32 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# 404 lidarseg,
# Done loading in 0.516 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ======
# scene-0061, Parked truck, construction, intersectio... [18-07-24 03:28:47]   19s, singapore-onenorth, #anns:4622
# scene-0103, Many peds right, wait for turning car, ... [18-08-01 19:26:43]   19s, boston-seaport, #anns:2046
# scene-0655, Parking lot, parked cars, jaywalker, be... [18-08-27 15:51:32]   20s, boston-seaport, #anns:2332
# scene-0553, Wait at intersection, bicycle, large tr... [18-08-28 20:48:16]   20s, boston-seaport, #anns:1950
# scene-0757, Arrive at busy intersection, bus, wait ... [18-08-30 19:25:08]   20s, boston-seaport, #anns:592
# scene-0796, Scooter, peds on sidewalk, bus, cars, t... [18-10-02 02:52:24]   20s, singapore-queensto, #anns:708
# scene-0916, Parking lot, bicycle rack, parked bicyc... [18-10-08 07:37:13]   20s, singapore-queensto, #anns:2387
# scene-1077, Night, big street, bus stop, high speed... [18-11-21 11:39:27]   20s, singapore-hollandv, #anns:890
# scene-1094, Night, after rain, many peds, PMD, ped ... [18-11-21 11:47:27]   19s, singapore-hollandv, #anns:1762
# scene-1100, Night, peds in sidewalk, peds cross cro... [18-11-21 11:49:47]   19s, singapore-hollandv, #anns:935

# %%
for scene in nusc.scene:
    token = scene['first_sample_token']
    frame_count = 0
    while token:
        frame_count += 1
        token = nusc.get('sample', token)['next']
    print(f"{scene['name']}: {frame_count} frames")
# Out:
# scene-0061: 39 frames
# scene-0103: 40 frames
# scene-0553: 41 frames
# scene-0655: 41 frames
# scene-0757: 41 frames
# scene-0796: 40 frames
# scene-0916: 41 frames
# scene-1077: 41 frames
# scene-1094: 40 frames
# scene-1100: 40 frames

# %%
def load_scenes(nusc):
    sample_dict = dict()
    sample_list = list()
    
    for scene in nusc.scene:
        scene_name = scene['name']
        token = scene['first_sample_token']
        print(f"[Processing {scene_name}...]")

        sample_list = list()
        frame_count = 0
        
        while token:
            frame = f"{frame_count:02d}"
            sample = nusc.get('sample', token)
            lidar_data = nusc.get('sample_data', sample['data']['LIDAR_TOP'])
            lidar_path = nusc.get_sample_data_path(lidar_data['token'])

            bin_ply_path = f"{nusc_path}/ply/bin/{scene_name}/{scene_name}_{frame}.ply"
            ascii_ply_path = f"{nusc_path}/ply/ascii/{scene_name}/{scene_name}_{frame}_ascii.ply"

            sample_list.append(
                {
                    'scene':    scene_name,
                    'frame':    frame,
                    'token':    token,
                    'lidar_path': lidar_path,
                    'bin_ply_path': bin_ply_path,
                    'ascii_ply_path': ascii_ply_path
                }
            )

            token = sample['next']
            frame_count += 1

        print(f">>> {frame_count} frames processed.")
        sample_dict[scene_name] = sample_list         
    return sample_dict

# %%
import json

sample_json = load_scenes(nusc)
json_path = f"{nusc_path}/nuscenes.json"

with open(json_path, "w") as f:
    json.dump(sample_json, f, indent=4, ensure_ascii=False)
# Out:
# [Processing scene-0061...]
# >>> 39 frames processed.
# [Processing scene-0103...]
# >>> 40 frames processed.
# [Processing scene-0553...]
# >>> 41 frames processed.
# [Processing scene-0655...]
# >>> 41 frames processed.
# [Processing scene-0757...]
# >>> 41 frames processed.
# [Processing scene-0796...]
# >>> 40 frames processed.
# [Processing scene-0916...]
# >>> 41 frames processed.
# [Processing scene-1077...]
# >>> 41 frames processed.
# [Processing scene-1094...]
# >>> 40 frames processed.
# [Processing scene-1100...]
# >>> 40 frames processed.

# %%
from plyfile import PlyData, PlyElement

def extract_ply(json, mode=0):
    source = json['lidar_path']
    
    if mode == 0: # binary
        ply_file = json['bin_ply_path']
    else:
        ply_file = json['ascii_ply_path']
    
    ply_dir = os.path.dirname(ply_file)
    if not os.path.exists(ply_dir):
        os.makedirs(ply_dir, exist_ok=True)

    try:
        data = np.fromfile(source, dtype=np.float32).reshape([-1,5])

        point = data[:, :3]
        refc = data[:, 3]
        ring = data[:, 4]

        vertex = np.empty(point.shape[0], dtype=[
            ('x', 'f4'),
            ('y', 'f4'),
            ('z', 'f4'),
            ('refc', 'u1'),
            ('ring', 'u1')
        ])

        vertex['x'] = point[:, 0]
        vertex['y'] = point[:, 1]
        vertex['z'] = point[:, 2]
        vertex['refc'] = refc
        vertex['ring'] = ring

        plydata = PlyData([PlyElement.describe(vertex, 'vertex')], text=mode)
        plydata.write(ply_file)
    
    except FileNotFoundError:
        print(f"File not found: {source}")
        sys.exit(1)

# %%
nuscenes_json = json_path

if not os.path.exists(nuscenes_json):
    raise ValueError("nuscenes.json does not exist")

else:
    with open(nuscenes_json, 'r') as f:
        data = json.load(f4)
        for scene_name, frames in data.items():
            for frame in frames:
                extract_ply(frame, 0)
            print(f"Extracted the {scene} point clouds.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/nuscenes/lib/python3.10/site-packages/plyfile.py:1461, in _lookup_type(type_str)
#    1460 try:
# -> 1461     type_str = _data_types[type_str]
#    1462 except KeyError:
#
# KeyError: 'f2'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 11
#       9 for scene_name, frames in data.items():
#      10     for frame in frames:
# ---> 11         extract_ply(frame, 0)
#      12     print(f"Extracted the {scene} point clouds.")
#
# Cell In[9], line 36, in extract_ply(json, mode)
#      33     vertex['refc'] = refc
#      34     vertex['ring'] = ring
# ---> 36     plydata = PlyData([PlyElement.describe(vertex, 'vertex')], text=mode)
#      37     plydata.write(ply_file)
#      39 except FileNotFoundError:
#
# File ~/miniconda3/envs/nuscenes/lib/python3.10/site-packages/plyfile.py:489, in PlyElement.describe(data, name, len_types, val_types, comments)
#     487     prop = PlyListProperty(t[0], len_str, val_str)
#     488 else:
# --> 489     val_str = _lookup_type(t[1][1:])
#     490     prop = PlyProperty(t[0], val_str)
#     492 properties.append(prop)
#
# File ~/miniconda3/envs/nuscenes/lib/python3.10/site-packages/plyfile.py:1463, in _lookup_type(type_str)
#    1461         type_str = _data_types[type_str]
#    1462     except KeyError:
# -> 1463         raise ValueError("field type %r not in %r" %
#    1464                          (type_str, _types_list))
#    1466 return _data_type_reverse[type_str]
#
# ValueError: field type 'f2' not in ['int8', 'i1', 'char', 'uint8', 'u1', 'uchar', 'b1', 'int16', 'i2', 'short', 'uint16', 'u2', 'ushort', 'int32', 'i4', 'int', 'uint32', 'u4', 'uint', 'float32', 'f4', 'float', 'float64', 'f8', 'double']
